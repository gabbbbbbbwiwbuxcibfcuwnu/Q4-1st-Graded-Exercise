# %% [markdown]
# <a href="https://colab.research.google.com/github/gabbbbbbbwiwbuxcibfcuwnu/Q4-1st-Graded-Exercise/blob/main/copy_of_nip_ipl_cxteam_dla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-fasthtml
# Out:
# Requirement already satisfied: python-fasthtml in /usr/local/lib/python3.12/dist-packages (0.14.3)
# Requirement already satisfied: fastcore>=1.12.45 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml) (1.13.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from python-fasthtml) (2.9.0.post0)
# Requirement already satisfied: starlette>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml) (1.3.1)
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.12/dist-packages (from python-fasthtml) (3.3.1)
# Requirement already satisfied: itsdangerous in /usr/local/lib/python3.12/dist-packages (from python-fasthtml) (2.2.0)
# Requirement already satisfied: uvicorn>=0.30 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml) (0.49.0)
# Requirement already satisfied: httpx2 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml) (2.4.0)
# Requirement already satisfied: fastlite>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml) (0.2.4)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (from python-fasthtml) (0.0.32)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml) (4.13.5)
# Requirement already satisfied: apswutils>=0.1.2 in /usr/local/lib/python3.12/dist-packages (from fastlite>=0.1.1->python-fasthtml) (0.1.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette>=1.0.1->python-fasthtml) (4.14.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from starlette>=1.0.1->python-fasthtml) (4.15.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.30->uvicorn[standard]>=0.30->python-fasthtml) (8.4.2)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.30->uvicorn[standard]>=0.30->python-fasthtml) (0.16.0)
# Requirement already satisfied: httptools>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml) (0.8.0)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml) (1.2.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml) (6.0.3)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml) (1.2.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->python-fasthtml) (2.8.4)
# Requirement already satisfied: httpcore2==2.4.0 in /usr/local/lib/python3.12/dist-packages (from httpx2->python-fasthtml) (2.4.0)
# Requirement already satisfied: idna>=3.18 in /usr/local/lib/python3.12/dist-packages (from httpx2->python-fasthtml) (3.18)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.12/dist-packages (from httpx2->python-fasthtml) (0.10.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->python-fasthtml) (1.17.0)
# Requirement already satisfied: apsw in /usr/local/lib/python3.12/dist-packages (from apswutils>=0.1.2->fastlite>=0.1.1->python-fasthtml) (3.53.2.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math

# =====================================================
# PARAMETERS
# =====================================================

GRID_SIZE = 601
CENTER = GRID_SIZE // 2

NUM_PARTICLES = 3600

grid = np.zeros((GRID_SIZE, GRID_SIZE), dtype=np.uint8)

# Seed particle
grid[CENTER, CENTER] = 1

Rmax = 5
Rs = 15
Rkill = 45

# =====================================================
# RELEASE PARTICLE
# =====================================================

def occupy():
    theta = random.uniform(0, 2 * math.pi)
    x = int(Rs * math.cos(theta))
    y = int(Rs * math.sin(theta))
    return x, y

# =====================================================
# RANDOM WALK
# =====================================================

def jump(x, y):

    r = random.randint(0, 3)

    if r == 0:
        x += 1
    elif r == 1:
        x -= 1
    elif r == 2:
        y += 1
    else:
        y -= 1

    return x, y

# =====================================================
# CHECK PARTICLE
# =====================================================

def check(x, y):

    gx = x + CENTER
    gy = y + CENTER

    if gx < 2 or gx >= GRID_SIZE-2:
        return "kill"

    if gy < 2 or gy >= GRID_SIZE-2:
        return "kill"

    r = math.sqrt(x*x + y*y)

    if r > Rkill:
        return "kill"

    # 8-neighbor check
    for dx in (-1,0,1):
        for dy in (-1,0,1):

            if dx == 0 and dy == 0:
                continue

            if grid[gx+dx, gy+dy]:
                return "stick"

    return "walk"

# =====================================================
# ADD PARTICLE
# =====================================================

def aggregate(x, y):

    global Rmax, Rs, Rkill

    gx = x + CENTER
    gy = y + CENTER

    grid[gx, gy] = 1

    r = math.sqrt(x*x + y*y)

    if r > Rmax:

        Rmax = r

        # Dynamic radii
        Rs = int(Rmax + 15)
        Rkill = int(Rmax + 45)

# =====================================================
# LONG JUMP
# =====================================================

def long_jump(x, y):

    r = math.sqrt(x*x + y*y)

    if r > Rs:

        theta = random.uniform(0, 2*math.pi)

        x += int((r - Rs) * math.cos(theta))
        y += int((r - Rs) * math.sin(theta))

    return x, y

# =====================================================
# MAIN SIMULATION
# =====================================================

for particle in range(NUM_PARTICLES):

    if particle % 1000 == 0:
        print(f"{particle}/{NUM_PARTICLES}")

    x, y = occupy()

    while True:

        x, y = jump(x, y)

        result = check(x, y)

        if result == "stick":
            aggregate(x, y)
            break

        elif result == "kill":
            x, y = occupy()

        else:

            r = math.sqrt(x*x + y*y)

            # Long-jump optimization
            if r > Rs + 10:
                x, y = long_jump(x, y)

# =====================================================
# DISPLAY
# =====================================================

plt.figure(figsize=(10,10), dpi=250)

plt.imshow(
    grid,
    cmap="binary",
    origin="lower",
    interpolation="nearest"
)

plt.title(f"Diffusion Limited Aggregation ({NUM_PARTICLES} particles)", fontsize=14)

plt.axis("off")

plt.show()
# Out:
# 0/3600
# 1000/3600
# 2000/3600
# 3000/3600
